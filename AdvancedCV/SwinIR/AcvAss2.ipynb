# %%
from google.colab import drive
drive.mount("/content/drive")
# !ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
import os

# %%
os.chdir("drive/MyDrive/acv_ass_2")

# %%
# !ls -al
# Out:
# total 230394
# -rw------- 1 root root       632 Apr 20 19:11 chname.py
# drwx------ 2 root root      4096 Apr 18 09:39 data
# -rw------- 1 root root      2179 Apr 18 17:07 evaluate.py
# drwx------ 2 root root      4096 Apr 18 17:28 .ipynb_checkpoints
# -rw------- 1 root root 113973105 Apr 21 14:27 iter_20000.pth
# -rw------- 1 root root      4609 Apr 18 09:56 low_config_new.py
# -rw------- 1 root root      5481 Apr 18 17:37 low_config_old.py
# drwx------ 2 root root      4096 Apr 18 10:39 mmediting
# -rw------- 1 root root      5502 Apr 19 17:36 model_config_new.py
# -rw------- 1 root root      5397 Apr 18 17:22 model_config.py
# drwx------ 2 root root      4096 Apr 18 17:15 save
# -rw------- 1 root root 104741147 Apr 21 20:11 sub.zip
# -rw------- 1 root root      6922 Apr 22 08:23 swinir_config_base.py
# -rw------- 1 root root  17154439 Apr 19 19:32 swinir_x4s64w8d4e60_8xb4-lr2e-4-500k_div2k-d6622d03.pth
# -rw------- 1 root root        39 Apr 18 10:56 temp.py
# ...

# %%
# !pip install -U openmim
# !mim install mmcv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 7.8 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.9/366.9 kB 28.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 27.2 MB/s eta 0:00:00
# ...

# %%
# !pip install torch
# !pip install pillow
# !pip install torchvision
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 91.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/open-mmlab/mmediting.git

# %%
os.chdir("mmediting")
# %pip install -e .
os.chdir("..")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/acv_ass_2/mmediting
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 56.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.0/852.0 kB 67.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.5/298.5 kB 37.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 23.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
#Do note that I have changed the code of this tool to show the precise parameter quantity.
# !python mmediting/tools/analysis_tools/get_flops.py model_config_new.py --shape 3 128 128
# !python mmediting/tools/analysis_tools/get_flops.py swinir_config_base.py --shape 3 128 128
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-04-22 08:22:58.359097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::leaky_relu_ encountered 2 time(s)
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::mul encountered 16 time(s)
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::add encountered 16 time(s)
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::pixel_shuffle encountered 2 time(s)
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::add_ encountered 1 time(s)
# 04/22 08:25:31 - mmengine - WARNING - Unsupported operator aten::upsample_bilinear2d encountered 1 time(s)
# ...

# %%
# %pip show mmedit
# Out:
# Name: mmedit
# Version: 1.0.0rc7
# Summary: OpenMMLab Image and Video Editing Toolbox and Benchmark
# Home-page: https://github.com/open-mmlab/mmediting
# Author:
# Author-email:
# License: Apache License 2.0
# Location: /content/drive/MyDrive/acv_ass_2/mmediting
# Editable project location: /content/drive/MyDrive/acv_ass_2/mmediting
# Requires: av, diffusers, einops, face-alignment, facexlib, lmdb, lpips, mmcv, mmengine, numpy, opencv-python, Pillow, resize_right, tensorboard
# Required-by:
# 1.0.0rc7

# %%
#finally
# !python mmediting/tools/train.py swinir_config_base.py
# Out:
# 04/21 14:33:51 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1118267924
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
os.chdir("/content/drive/MyDrive/acv_ass_2")
# !python mmediting/tools/test.py swinir_config_base.py work_dirs/swinir/best_PSNR_iter_50000.pth
# Out:
# 04/22 09:13:48 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 121702045
#     GPU 0: NVIDIA A100-SXM4-40GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
# ...

# %%
# !python chname.py --path "swinir/20230421_200216"

os.chdir(r"work_dirs/swinir/20230421_200216/vis_data/vis_image")
# !zip -q -r sub.zip *.png
# !mv sub.zip /content/drive/MyDrive/acv_ass_2/
os.chdir("/content/drive/MyDrive/acv_ass_2")
# Out:
# chname.py: task finished.
